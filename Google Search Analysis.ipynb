# %%
# !pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\anaconda\lib\site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in c:\anaconda\lib\site-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\anaconda\lib\site-packages (from pytrends) (2.0.3)
# Requirement already satisfied: lxml in c:\anaconda\lib\site-packages (from pytrends) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=0.25->pytrends) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\lib\site-packages (from pandas>=0.25->pytrends) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\anaconda\lib\site-packages (from pandas>=0.25->pytrends) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests>=2.0->pytrends) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests>=2.0->pytrends) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   56
# Singapore                  54
# India                      44
# Sri Lanka                  32
# Tunisia                    31
# Pakistan                   30
# South Korea                30
# Nepal                      27
# Hong Kong                  27

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
from pytrends.request import TrendReq

# Setting higher timeout
data = TrendReq(hl='en-US', tz=360, timeout=(10, 25))  # increase timeout
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
